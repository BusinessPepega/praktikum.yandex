# %% [markdown]
# <div style="border:solid black 2px; padding: 20px">
# <b>Привет!</b>
#
# Меня зовут Полина Бережная, и я буду делать ревью проекта по машинному обучению. Давай будем общаться на «ты». Но если тебе комфортнее на «вы», обязательно сообщи мне об этом.
#
# Твой проект просто 🔥🔥🔥. Видно, что ты уверенно кодишь и понимаешь базу машинного обучения. Однако есть пара моментов, которые требуют твоего внимания и доработки.
#
# В тетрадке ты можешь встретить 4 вида моих комментариев:
# - <div class="alert alert-danger">
#   <h3>Комментарий ревьюера</h3> Такой нюанс требует обязательной доработки, иначе проект не будет принят.
#   </div>
#
#
# - <div class="alert alert-warning">
#   <h3>Комментарий ревьюера</h3> Так выделены не обязательные к доработке моменты. Mожешь учесть их при редактировании проекта и выполнении будущих заданий. На твое усмотрение.
#   </div>
#
#
# - <div class="alert alert-success">
#   <h3>Комментарий ревьюера</h3> Так отмечены удачные решения и подходы, на которые стоит опираться в будущих проектах.
#   </div>
#
#
# - <div style="border:solid black 2px; padding: 20px">
#   <h3>Чек-лист доработок</h3> Такой комментарий будет находиться в конце тетрадки. В нем будут еще раз указаны нюансы, требующие обязательной корректировки.
#   </div>
#
# Предлагаю работать над проектом в форме диалога: если ты **что-то меняешь** в работе по моим рекомендациям — **пиши об этом** и помечай комментарий каким-то заметным цветом. Пожалуйста, **не перемещай, не изменяй и не удаляй мои комментарии**. Такой формат работы поможет выполнить повторную проверку твоего проекта оперативнее.
#
# Не переживай, если что-то не получилось сделать идеально с первого раза. Основная цель нашей команды - не найти ошибки, а поделиться своим опытом и помочь тебе стать профи в аналитике 🙂
#
# Жду твой проект на повторное ревью, ты уже почти на финише!
#
#
# </div>

# %% [markdown]
# <div style="border:solid black 2px; padding: 20px">
# <b>Привет еще раз!</b>
#
# Проект доработан на отлично, он принят! Желаю тебе успехов в карьере и всех будущих начинаниях!

# %% [markdown]
# <a id='Оглавление'></a>
# ### [Описание проекта](#Описание_проекта)
# ### [Загрузка данных](#Загрузка_данных)
# ### [Исследовательский анализ данных](#Анализ_данных)
# ### [Модель прогнозирования оттока клиентов](#прогнозирования_оттока)
# ### [Кластеризация клиентов](#Кластеризация)
# ### [Общий вывод](#вывод)

# %% [markdown]
# <a id='Описание_проекта'></a>
# ## Описание проекта (контекст)
# [Оглавление](#Оглавление)

# %% [markdown]
# Сеть фитнес-центров «Культурист-датасаентист» разрабатывает стратегию взаимодействия с клиентами на основе аналитических данных.
# Распространённая проблема фитнес-клубов и других сервисов — отток клиентов. Как понять, что клиент больше не с вами? Можно записать в отток тех, кто попросил закрыть договор или удалил аккаунт. Однако клиенты не всегда уходят демонстративно: чаще перестают пользоваться сервисом тихо.
# Индикаторы оттока зависят от специфики отрасли. Когда пользователь редко, но стабильно закупается в интернет-магазине — не похоже, что он «отвалился». А вот если две недели не заходит на канал с ежедневно обновляемым контентом, дела плохи: подписчик заскучал и, кажется, оставил вас.
# Для фитнес-центра можно считать, что клиент попал в отток, если за последний месяц ни разу не посетил спортзал. Конечно, не исключено, что он уехал на Бали и по приезде обязательно продолжит ходить на фитнес. Однако чаще бывает наоборот. Если клиент начал новую жизнь с понедельника, немного походил в спортзал, а потом пропал — скорее всего, он не вернётся.
# Чтобы бороться с оттоком, отдел по работе с клиентами «Культуриста-датасаентиста» перевёл в электронный вид множество клиентских анкет. Ваша задача — провести анализ и подготовить план действий по удержанию клиентов.
#           А именно:
# научиться прогнозировать вероятность оттока (на уровне следующего месяца) для каждого клиента;
# сформировать типичные портреты клиентов: выделить несколько наиболее ярких групп и охарактеризовать их основные свойства;
# проанализировать основные признаки, наиболее сильно влияющие на отток;
# сформулировать основные выводы и разработать рекомендации по повышению качества работы с клиентами:
# * выделить целевые группы клиентов;
# * предложить меры по снижению оттока;
# * определить другие особенности взаимодействия с клиентами.

# %% [markdown]
# <div class="alert alert-success">
# <h3> Комментарий ревьювера</h3>
#
# Здорово, что перед кодом есть описание задач проекта и данных, а также план твоих действий с навигацией 👍🏻. Да и все оформление тетрадки выполнено на достойном уровне. Она рассказывает историю за тебя и показывает как твои кодинговые навыки, так и умение анализировать и преподносить информацию :)

# %% [markdown]
# <a id='Загрузка_данных'></a>
# ## Загрузка данных
# [Оглавление](#Оглавление)

# %%
import pandas as pd

# %%
df = pd.read_csv('/datasets/gym_churn.csv')

# %% [markdown]
# - 'Churn' — факт оттока в текущем месяце;
# - Текущие поля в датасете:
#     Данные клиента за предыдущий до проверки факта оттока месяц:
#     - 'gender' — пол;
#     - 'Near_Location' — проживание или работа в районе, где находится фитнес-центр;
#     - 'Partner' — сотрудник компании-партнёра клуба (сотрудничество с компаниями, чьи сотрудники могут получать скидки на абонемент — в таком случае фитнес-центр хранит информацию о работодателе клиента);
#     - Promo_friends — факт первоначальной записи в рамках акции «приведи друга» (использовал промо-код от знакомого при оплате первого абонемента);
#     - 'Phone' — наличие контактного телефона;
#     - 'Age' — возраст;
#     - 'Lifetime' — время с момента первого обращения в фитнес-центр (в месяцах).
# - Информация на основе журнала посещений, покупок и информация о текущем статусе абонемента клиента:
#     - 'Contract_period' — длительность текущего действующего абонемента (месяц, 3 месяца, 6 месяцев, год);
#     - 'Month_to_end_contract' — срок до окончания текущего действующего абонемента (в месяцах);
#     - 'Group_visits' — факт посещения групповых занятий;
#     - 'Avg_class_frequency_total' — средняя частота посещений в неделю за все время с начала действия абонемента;
#     - 'Avg_class_frequency_current_month' — средняя частота посещений в неделю за предыдущий месяц;
#     - 'Avg_additional_charges_total' — суммарная выручка от других услуг фитнес-центра: кафе, спорт-товары, косметический и массажный салон.

# %%
df
# Out:
#       gender  Near_Location  Partner  Promo_friends  Phone  Contract_period  \
# 0          1              1        1              1      0                6
# 1          0              1        0              0      1               12
# 2          0              1        1              0      1                1
# 3          0              1        1              1      1               12
# 4          1              1        1              1      1                1
# ...      ...            ...      ...            ...    ...              ...
# 3995       1              1        1              0      1               12
# 3996       0              1        0              0      1                1
# 3997       1              1        1              1      1               12
# 3998       0              1        1              1      1                6
# 3999       1              0        1              0      0               12
#
# ...

# %%
df.columns = df.columns.str.lower()

# %%
df.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Columns: 14 entries, gender to churn
# dtypes: float64(4), int64(10)
# memory usage: 437.6 KB

# %%
df.isna().sum()
# Out:
# gender                               0
# near_location                        0
# partner                              0
# promo_friends                        0
# phone                                0
# contract_period                      0
# group_visits                         0
# age                                  0
# avg_additional_charges_total         0
# month_to_end_contract                0
# lifetime                             0
# avg_class_frequency_total            0
# avg_class_frequency_current_month    0
# churn                                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Вывод:
#
# Исходные данные поступили в готовом к анализу виде.

# %% [markdown]
# <div class="alert alert-success">
# <h3> Комментарий ревьювера</h3>
#
# Ты отлично владеешь методами первичного изучения данных 👍🏻

# %% [markdown]
# <a id='Анализ_данных'></a>
# ## Исследовательский анализ данных (EDA)
# [Оглавление](#Оглавление)

# %% [markdown]
# #### Посмотрим на датасет: есть ли в нем отсутствующие признаки, изучим средние значения и стандартные отклонения (пригодится метод describe()):

# %%
df.describe()
# Out:
#             gender  near_location      partner  promo_friends        phone  \
# count  4000.000000    4000.000000  4000.000000    4000.000000  4000.000000
# mean      0.510250       0.845250     0.486750       0.308500     0.903500
# std       0.499957       0.361711     0.499887       0.461932     0.295313
# min       0.000000       0.000000     0.000000       0.000000     0.000000
# 25%       0.000000       1.000000     0.000000       0.000000     1.000000
# 50%       1.000000       1.000000     0.000000       0.000000     1.000000
# 75%       1.000000       1.000000     1.000000       1.000000     1.000000
# max       1.000000       1.000000     1.000000       1.000000     1.000000
#
#        contract_period  group_visits          age  \
# count      4000.000000   4000.000000  4000.000000
# mean          4.681250      0.412250    29.184250
# std           4.549706      0.492301     3.258367
# min           1.000000      0.000000    18.000000
# ...

# %% [markdown]
#  Если я правильно понял, то средний посетитель:
#    - Может быть любого пола почти 50/50
#    - Проживает в одном районе с залом
#    - 50/50 является сотрудником компании-партнёра клуба
#    - пришел самостоятельно (без приглашения от друзей)
#    - преобретает обанемент на 3+ месяца
#    - не посещает групповые занятия
#    - 29 лет
#    - потратил на дополнительные услуги 147 чего-то
#    - до окончания абонемента 4+ месяца
#    - посещает зал более 3 месяцев
#    - стабильно за последний месяц посещал зал около около 2х раз в неделю
#    - факт оттока в текущем месяце не подтвержден

# %% [markdown]
# <div class="alert alert-danger">
# <h3> Комментарий ревьювера</h3>
#
# По данной табличке необходимо составить портрет среднестатистического клиента. Добавь, пожалуйста :)

# %% [markdown]
# <div class="alert alert-success">
# <h3> Комментарий ревьювера v2</h3>
#
# Отлично 👍🏻

# %% [markdown]
# <div class="alert alert-warning">
# <h3> Комментарий ревьювера</h3>
#
# Хотелось бы обратить внимание, например, на переменные Age и Avg_additional_charges_total. У них очень разные по величине стандартные отклонения.
# Это говорит о том, что переменные нужно стандартизировать перед обучением. Для логистической регрессии и дерева это не обязательно, но вообще это уже такое внегласное правило. Лучше сразу стандартизировать все, а потом уже гонять модели. Что ты и было сделано:) Стоит указывать на данный нюанс в выводе.

# %% [markdown]
# #### Посмотрим на средние значения признаков в двух группах — тех, кто ушел в отток и тех, кто остался (воспользуемся методом groupby())

# %%
df.head()
# Out:
#    gender  near_location  partner  promo_friends  phone  contract_period  \
# 0       1              1        1              1      0                6
# 1       0              1        0              0      1               12
# 2       0              1        1              0      1                1
# 3       0              1        1              1      1               12
# 4       1              1        1              1      1                1
#
#    group_visits  age  avg_additional_charges_total  month_to_end_contract  \
# 0             1   29                     14.227470                    5.0
# 1             1   31                    113.202938                   12.0
# 2             0   28                    129.448479                    1.0
# 3             1   33                     62.669863                   12.0
# 4             0   26                    198.362265                    1.0
#
#    lifetime  avg_class_frequency_total  avg_class_frequency_current_month  \
# ...

# %%
df.groupby('churn').agg('mean').T
# Out:
# churn                                       0           1
# gender                               0.510037    0.510839
# near_location                        0.873086    0.768143
# partner                              0.534195    0.355325
# promo_friends                        0.353522    0.183789
# phone                                0.903709    0.902922
# contract_period                      5.747193    1.728558
# group_visits                         0.464103    0.268615
# age                                 29.976523   26.989632
# avg_additional_charges_total       158.445715  115.082899
# month_to_end_contract                5.283089    1.662582
# lifetime                             4.711807    0.990575
# avg_class_frequency_total            2.024876    1.474995
# avg_class_frequency_current_month    2.027882    1.044546

# %% [markdown]
# #### Построим столбчатые гистограммы и распределения признаков для тех, кто ушёл (отток) и тех, кто остался (не попали в отток)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#df

# %%
#df.columns

# %% [markdown]
# Не все признаки при построении графиков имели информативный вид, пришлось некоторые графики пропустить

# %%
columns = ['gender', 'near_location', 'partner', 'promo_friends', 'phone',
       'contract_period', 'group_visits', 'age',
       'month_to_end_contract', 'lifetime', 'churn']

# %%
for column in columns:
    plt.figure(figsize=(6, 5))
    sns.countplot(data=df, x = df[column], hue='churn')
    plt.title(column)
    plt.show()

# %% [markdown]
# ### Вывод:
# - пол не влияет
# - кто проживает ближе, те бросают больше
# - сотрудники прекращают пользоваться залом меньше, чем не сотрудники
# - кто пришел с другом, продолжают заниматься охотнее
# - признак с номером телефона очень странный, таких очень мало и непонятно, как им удалось утаить эту информацию.
# - длительность действующего контракта говорит нам, что самый важный это первый месяц посещения
# - групповые занятия удерживают поситителей значитеьно лучше
# - до 25 лет бросающих больше продолжающих заниматься, а вот с 26 резко картина меняется и до 30 только улучшается
# - остаток контракта снова говорит нам, что люди берут абонемент на 1 месяц и принимают далбнейшее решение по его истечению
# - начиная со второго месяца отток значительно сокращается и на 5 правтически равен нулю

# %%
columns_2 = ['age', 'avg_additional_charges_total', 'month_to_end_contract', 'lifetime',
        'avg_class_frequency_total', 'avg_class_frequency_current_month']

# %%
for column in columns_2:
    plt.figure(figsize=(6, 6))
    sns.boxplot(data = df, x = 'churn', y = df[column])
    plt.title(column)
    plt.show()

# %% [markdown]
# ### Вывод:
# - Кто тратит меньше на дополнительные услуги тот вероятнее уйдет и не вернется
# - Кто ходит менее 2 раз в неделю менее склонны к продлению абонемента

# %% [markdown]
# <div class="alert alert-success">
# <h3> Комментарий ревьювера</h3>
#
# Отличный анализ и эстетичные визуализации 🔥

# %% [markdown]
# #### Построим матрицу корреляций и отобразим её.

# %%
cm = df.corr()
plt.figure(figsize=(14, 10))
sns.heatmap(cm, annot = True, fmt = '0.2f', cmap="YlGnBu")
plt.show()

# %% [markdown]
# ### Вывод:
#
#  - Признаки мультиколлинеарны:
#      - contract_period - month_to_end_contract
#      - avg_class_frequency_current_month - avg_class_frequency_total мультиколлинеарны
#  - gender и phone имеют нулевую корреляцию с целевой переменной

# %% [markdown]
# <div class="alert alert-success">
# <h3> Комментарий ревьювера</h3>
#
# Все верно! Одну переменную из пары мультиколлинеарных признаков стоит удалять, иначе она будет доминировать при обучении.

# %% [markdown]
# <a id='прогнозирования_оттока'></a>
# ## Модель прогнозирования оттока клиентов
# [Оглавление](#Оглавление)

# %%
from sklearn.cluster import KMeans
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# #### Разобьем данные на обучающую и валидационную выборку функцией train_test_split()

# %%
X = df.drop('churn', axis = 1)
y = df['churn']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# <div class="alert alert-warning">
# <h3>Комментарий ревьюера</h3>
#
# Можно использовать параметр stratify = y в функции train_test_split( ), где y – соответствующая целевая переменная. Данные разделятся на два кластера (наблюдения класса 0 и наблюдения класса 1), и в валидационную выборку попадут по 20% наблюдений из каждого кластера:
#
# ![111.jpeg](attachment:111.jpeg)
#
# То есть, если соотношение классов в оригинальной выборке было 2:5, то в обучающей и валидационной выборках оно сохранится таким же. Такой подход в чем-то решает проблему несбалансированных классов.

# %% [markdown]
# #### Обучим модель на train-выборке логистической регрессией

# %%
model = LogisticRegression(solver='liblinear')

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='liblinear', tol=0.0001, verbose=0,
#                    warm_start=False)

# %% [markdown]
# <div class="alert alert-warning">
# <h3>Комментарий ревьюера</h3>
#
# Предупреждение можно убрать указав параметр solver в теле функции LogisticRegression( ).

# %% [markdown]
# <div class="alert alert-info">
#
# Поставил дефолтное значение из предыдущей версии, т.к. ‘lbfgs’ (документация для актуальной) не помогло
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <h3> Комментарий ревьювера v2</h3>
#
# Скорее всего там была новая ошибка, связанная с аргументом max_iter. Если увеличить его значение, то ошибка пропадет, так как алгоритму хватит итерация для нахождения оптимума.

# %%
predictions = model.predict(X_test)
probabilities =  model.predict_proba(X_test)[:,1]

# %%
print('\tAccuracy: {:.2f}'.format(accuracy_score(y_test, predictions)))
print('\tPrecision: {:.2f}'.format(precision_score(y_test, predictions)))
print('\tRecall: {:.2f}'.format(recall_score(y_test, predictions)))
print('\tF1: {:.2f}'.format(f1_score(y_test, predictions)))
# Out:
# 	Accuracy: 0.93
# 	Precision: 0.86
# 	Recall: 0.83
# 	F1: 0.85

# %% [markdown]
# #### Обучим модель на train-выборке случайным лесом

# %%
scaler = StandardScaler()
scaler.fit(X_train)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
X_train_st = scaler.transform(X_train)
X_test_st = scaler.transform(X_test)

# %%
rf_model = RandomForestClassifier(n_estimators = 100, random_state = 0) 
rf_model.fit(X_train_st, y_train)
rf_predictions = rf_model.predict(X_test_st) 
rf_probabilities = rf_model.predict_proba(X_test_st)[:,1]

# %%
print('\tAccuracy: {:.2f}'.format(accuracy_score(y_test, rf_predictions)))
print('\tPrecision: {:.2f}'.format(precision_score(y_test, rf_predictions)))
print('\tRecall: {:.2f}'.format(recall_score(y_test, rf_predictions)))
print('\tF1: {:.2f}'.format(f1_score(y_test, rf_predictions)))
# Out:
# 	Accuracy: 0.92
# 	Precision: 0.84
# 	Recall: 0.81
# 	F1: 0.83

# %% [markdown]
# ### Вывод:
#
# Модель с логистической регрессией на основании метрик показала себя лучше

# %% [markdown]
# <div class="alert alert-success">
# <h3> Комментарий ревьювера</h3>
#
# Этап выполнен абсолютно корректно! Молодец!

# %% [markdown]
# <a id='Кластеризация'></a>
# ## Кластеризация клиентов
# [Оглавление](#Оглавление)

# %% [markdown]
# #### Стандартизируем данные

# %%
sc = StandardScaler()
X_sc = sc.fit_transform(X)

# %% [markdown]
# #### Построим матрицу расстояний функцией linkage() на стандартизованной матрице признаков и нарисуем дендрограмму

# %%
linked = linkage(X_sc, method = 'ward')

# %%
plt.figure(figsize=(20, 10))  
dendrogram(linked, orientation='top')
plt.show()

# %% [markdown]
# #### Обучим модель кластеризации на основании алгоритма K-Means и спрогнозируем кластеры клиентов. Договоримся за число кластеров принять n=5

# %% [markdown]
# <div class="alert alert-success">
# <h3> Комментарий ревьювера</h3>
#
# Согласна :)

# %% [markdown]
# <div class="alert alert-danger">
# <h3> Комментарий ревьювера</h3>
#
# Необходимо указать random_state, иначе при перезапуске кода деление на кластеры все время будет разным. Поправь, пожалуйста, и проанализируй изменения :)

# %% [markdown]
# <div class="alert alert-success">
# <h3> Комментарий ревьювера v2</h3>
#
# 👍🏻

# %%
km = KMeans(n_clusters = 5, random_state=0)
labels = km.fit_predict(df)
df['cluster'] = labels

# %% [markdown]
# #### Посмотрим на средние значения признаков для кластеров

# %%
df.groupby('cluster').mean().T
# Out:
# cluster                                     0           1           2  \
# gender                               0.514091    0.511435    0.468635
# near_location                        0.839650    0.844075    0.856089
# partner                              0.451895    0.495842    0.516605
# promo_friends                        0.279883    0.320166    0.332103
# phone                                0.897959    0.902287    0.926199
# contract_period                      4.301263    4.755717    5.822878
# group_visits                         0.407191    0.423077    0.431734
# age                                 28.973761   29.401247   29.845018
# avg_additional_charges_total       105.932804  174.873445  356.481960
# month_to_end_contract                3.996113    4.376299    5.383764
# lifetime                             3.544218    3.749480    4.420664
# avg_class_frequency_total            1.852564    1.895200    2.019260
# ...

# %% [markdown]
# ### Наблюдение:
#
# Кластер 2 самый преданный спорту. Его выделяет: наивысший средний возраст,  высокие траты на дополнительные услуги, не менее 2х тренировок еженедельно и длительный срок посещений с первого визита и время до истечения контракта.

# %% [markdown]
# #### Построим распределение признаков для кластеров

# %%
for column in columns:
    plt.figure(figsize=(12, 6))
    sns.countplot(data=df, x = df[column], hue='cluster')
    plt.title(column)
    plt.show()

# %% [markdown]
# ### Наблюдение:
# Кластеры очень не равны количественно

# %%
for column in columns_2:
    plt.figure(figsize=(12, 10))
    sns.boxplot(x = 'cluster', y = df[column], data = df)
    plt.title(column)
    plt.show()

# %% [markdown]
# Отличительные особенности групп клиентов (кластеров):
#
# Кластер 0 и 3 самые утекающие и практически идетничны (отток более 30%):
#   - Самый низкий процент привлечения, через "приведи друга"
#   - Меншье всех посещают групповые занятия
#   - Посещают зал менее 2 раз в неделю
#   - Тратят на доп услуги меньше остальных (НО! кластер 0 тратит более чем в два раза больше 3го)
#   - самый низкий средний возраст
#   - являются клиентами около трех месяцев
#   - приобретают абонементы на более короткий срок
#
# Кластеры 1 и 4 являются средними по оттоку и демонстрируют схожесть (отток 22% и 17% соответственно):
#   - являются клиентами около 4 месяцев
#   - активно посещают групповые занятия
#   - активнее записываются по акции "приведи друга"
#   - средний возраст 29+
#   - действующий абонемент на 4+ месяца
#
# Кластер 2 (отток 4%):
#   - самый возрастной
#   - значительно больше тратит на доп. услуги
#   - состоит на половину из партнеров клуба
#   - преобретает более длительные абонементы
#   - является постоянным клиентом более 4х месяцев
#   - в среднем стабильно посещает зал не менее 2х раз в неделю

# %% [markdown]
# <div class="alert alert-danger">
# <h3> Комментарий ревьювера</h3>
#
# Все верно! Но нам важно знать профили разных групп клиентов. Не мог бы добавить краткие портреты кластеров?)

# %% [markdown]
# <div class="alert alert-success">
# <h3> Комментарий ревьювера v2</h3>
#
# Замечательный анализ 👍🏻

# %% [markdown]
# #### Для каждого полученного кластера посчитаем долю оттока (методом groupby())

# %%
df.groupby(['cluster'])['churn'].mean().sort_values()
# Out:
# cluster
# 2    0.044280
# 4    0.178470
# 1    0.226611
# 0    0.334305
# 3    0.349806
# Name: churn, dtype: float64

# %% [markdown]
# <a id='вывод'></a>
# ### Общий вывод
# [Оглавление](#Оглавление)

# %% [markdown]
# В целом можно подтягивать показатели других кластеров под 2й, но он самый малочисленный и там скорей всего самые крепкие любители спорта, которые являются исключением и равняться на все это может быть ошибкой.
#
# Но, на разных этапах исследования все-таки были выявлены некоторые закономерности
# - Нужно улучшить и продвигать программу "приведи друга" и различные групповые занятия
# - Сфокусироваться на рекламе в районе расположения зала и на клиентах старше 25 лет
# - Мотивировать посещения не менее 2х раз в неделю и предлагать (или развивать) доп. услуги
# - Сделать привлекательные цены на длительные абонементы, чем больше осталось, тем тяжелее "выкидывать"

# %% [markdown]
# <div style="border:solid black 2px; padding: 20px">
# <h3>Чек-лист доработок</h3>
#
# Твой проект просто 🔥, но мы его сделаем прям 🔥🔥🔥
#
# Прошу тебя:
# 1. **Добавить описание среднестатистического клиента.**
# 2. **Доработать этап кластеризации.**
#
# Жду твой проект на повторное ревью, осталось совсем чуть-чуть. Не стесняйся оставлять комментарии и задавать вопросы. Удачи! Все получится 🙂
