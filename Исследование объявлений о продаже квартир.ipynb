# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
# <b>Привет!</b>
#
# Меня зовут Евгений Д., и я буду проверять твой проект. Предлагаю общаться на «ты» 😊 Но если это не удобно - дай знать, и мы перейдем на "вы".
#
# Моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе стать аналитиком данных. Ты уже проделал большую работу над проектом, но давай сделаем его еще лучше. Ниже ты найдешь мои комментарии - пожалуйста, не перемещай, не изменяй и не удаляй их. Я буду использовать цветовую разметку:
#
# <div class="alert alert-danger">
# <b>Комментарий ревьюера:</b> Так выделены самые важные замечания. Без их отработки проект не будет принят. </div>
#
# <div class="alert alert-warning">
# <b>Комментарий ревьюера:</b> Так выделены небольшие замечания. Одна-два таких замечания в проекте допустимы, но если их будет больше - тебе будет необходимо внести исправления. Это как тестовое задание при приеме на работу: очень много мелких ошибок могут стать причиной отказа кандидату.
#
# </div>
#
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b> Так я выделяю все остальные комментарии.</div>
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комменатри — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
# <div class="alert alert-info"> <b>Комментарий студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее.

# %% [markdown]
# <a id='Оглавление'></a>
# ### [Цель проекта](#Цель_проекта)
# ### [Описание данных](#Описание_данных)
# ### [Первичное знакомство с данными](#Первичное_знакомство_с_данными)
# ### [Предобработка данных](#Предобработка_данных)
# * #### [Обработка пропусков](#Обработка_пропусков)
#  * ##### [Столбец ceiling_height](#Столбец_ceiling_height)
#  * ##### [Столбец floors_total](#Столбец_floors_total)
#  * ##### [Столбец living_area](#Столбец_living_area)
#  * ##### [Столбец is_apartment](#is_apartment)
#  * ##### [Столбец kitchen_area](#Столбец_kitchen_area)
#  * ##### [Столбец balcony](#Столбец_balcony)
#  * ##### [Столбец locality_name](#Столбец_locality_name)
#  * ##### [Картографические пропуски](#gps)
#  * ##### [Столбец days_exposition](#Столбец_days_exposition)
# * #### [Обработка дубликатов](#Обработка_дубликатов)
# * #### [Изменение типа данных](#Изменение_типа_данных)
# ### [Модификация таблицы](#Расширение_таблицы)
# ### [Исследовательский анализ данных](#Исследовательский_анализ_данных)
# * #### [Основные параметры помещений](#параметры)
#  * #### [Параметр: площадь](#площадь)
#  * #### [Параметр: цена](#цена)
#  * #### [Параметр: комнаты](#комнаты)
#  * #### [Параметр: потолки](#потолки)
# * #### [Время продажи](#Время_продажи)
# * #### [Влияние факторов на стоимость](#Влияние_факторов)
# * #### [10 населённых пунктов с наибольшим числом объявлений](#населённых_пункто)
# * #### [Определение центральной зоны](#центральной_зоны)
# * #### [Сегмент квартир в центре](#Сегмент_квартир)
# ### [Общий вывод](#Общий_вывод)

# %% [markdown]
# <a id='Цель_проекта'></a>
# ## Цель проекта: Исследование объявлений о продаже квартир
# [Оглавление](#Оглавление)
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# <a id='Описание_данных'></a>
# ## Описание данных
# [Оглавление](#Оглавление)
#
# * airports_nearest — расстояние до ближайшего аэропорта в метрах (м)
# * balcony — число балконов
# * ceiling_height — высота потолков (м)
# * cityCenters_nearest — расстояние до центра города (м)
# * days_exposition — сколько дней было размещено объявление (от публикации до снятия)
# * first_day_exposition — дата публикации
# * floor — этаж
# * floors_total — всего этажей в доме
# * is_apartment — апартаменты (булев тип)
# * kitchen_area — площадь кухни в квадратных метрах (м²)
# * last_price — цена на момент снятия с публикации
# * living_area — жилая площадь в квадратных метрах(м²)
# * locality_name — название населённого пункта
# * open_plan — свободная планировка (булев тип)
# * parks_around3000 — число парков в радиусе 3 км
# * parks_nearest — расстояние до ближайшего парка (м)
# * ponds_around3000 — число водоёмов в радиусе 3 км
# * ponds_nearest — расстояние до ближайшего водоёма (м)
# * rooms — число комнат
# * studio — квартира-студия (булев тип)
# * total_area — площадь квартиры в квадратных метрах (м²)
# * total_images — число фотографий квартиры в объявлении
#
# Пояснение: апартаменты — это нежилые помещения, не относящиеся к жилому фонду, но имеющие необходимые условия для проживания.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера</h2>
#
# Вступление в работу очень важно. Так ты поясняешь то, чему она посвящена 👍
#
# </div>

# %% [markdown]
# <a id='Первичное_знакомство_с_данными'></a>
# ### Первичное знакомство с данными
# [Оглавление](#Оглавление)

# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import pprint
from datetime import datetime
from pymystem3 import Mystem
from collections import Counter

# %%
pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv('/datasets/real_estate_data.csv')

# %%
data.head()
# Out:
#   total_images\tlast_price\ttotal_area\tfirst_day_exposition\trooms\tceiling_height\tfloors_total\tliving_area\tfloor\tis_apartment\tstudio\topen_plan\tkitchen_area\tbalcony\tlocality_name\tairports_nearest\tcityCenters_nearest\tparks_around3000\tparks_nearest\tponds_around3000\tponds_nearest\tdays_exposition
# 0  20\t13000000.0\t108.0\t2019-03-07T00:00:00\t3\...
# 1  7\t3350000.0\t40.4\t2018-12-04T00:00:00\t1\t\t...
# 2  10\t5196000.0\t56.0\t2015-08-20T00:00:00\t2\t\...
# 3  0\t64900000.0\t159.0\t2015-07-24T00:00:00\t3\t...
# 4  2\t10000000.0\t100.0\t2018-06-19T00:00:00\t2\t...

# %%
data = pd.read_csv('/datasets/real_estate_data.csv', sep = '\t')

# %%
data.head(20)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1              7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2             10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3              0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4              2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5             10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6              6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7              5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8             20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9             18   5400000.0       61.00  2017-02-26T00:00:00      3
# 10             5   5050000.0       39.60  2017-11-16T00:00:00      1
# 11             9   3300000.0       44.00  2018-08-27T00:00:00      2
# 12            10   3890000.0       54.00  2016-06-30T00:00:00      2
# ...

# %%
data.tail(10)
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 23689            13   3550000.0       35.30  2018-02-28T00:00:00      1
# 23690             3   5500000.0       52.00  2018-07-19T00:00:00      2
# 23691            11   9470000.0       72.90  2016-10-13T00:00:00      2
# 23692             2   1350000.0       30.00  2017-07-07T00:00:00      1
# 23693             9   4600000.0       62.40  2016-08-05T00:00:00      3
# 23694             9   9700000.0      133.81  2017-03-21T00:00:00      3
# 23695            14   3100000.0       59.00  2018-01-15T00:00:00      3
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23697            13  11475000.0       76.75  2017-03-28T00:00:00      2
# 23698             4   1350000.0       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 23689            2.86          15.0         16.3      4          NaN   False
# ...

# %%
data.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  23699.000000  2.369900e+04  23699.000000  23699.000000    14504.000000
# mean       9.858475  6.541549e+06     60.348651      2.070636        2.771499
# std        5.682529  1.088701e+07     35.654083      1.078405        1.261056
# min        0.000000  1.219000e+04     12.000000      0.000000        1.000000
# 25%        6.000000  3.400000e+06     40.000000      1.000000        2.520000
# 50%        9.000000  4.650000e+06     52.000000      2.000000        2.650000
# 75%       14.000000  6.800000e+06     69.900000      3.000000        2.800000
# max       50.000000  7.630000e+08    900.000000     19.000000      100.000000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  23613.000000  21796.000000  23699.000000  21421.000000  12180.000000
# mean      10.673824     34.457852      5.892358     10.569807      1.150082
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
# total_images            23699 non-null int64
# last_price              23699 non-null float64
# total_area              23699 non-null float64
# first_day_exposition    23699 non-null object
# rooms                   23699 non-null int64
# ceiling_height          14504 non-null float64
# floors_total            23613 non-null float64
# living_area             21796 non-null float64
# floor                   23699 non-null int64
# is_apartment            2775 non-null object
# studio                  23699 non-null bool
# open_plan               23699 non-null bool
# kitchen_area            21421 non-null float64
# balcony                 12180 non-null float64
# locality_name           23650 non-null object
# airports_nearest        18157 non-null float64
# cityCenters_nearest     18180 non-null float64
# parks_around3000        18181 non-null float64
# ...

# %% [markdown]
# ### Вывод:
#
# - больше половины столбцов имеют пропуски
# - есть 900 метровая площадь
# - есть 100 метровый потолок
# - 60 этажное здание
# - 65км до центра города
# - last_price, floors_total, balcony, parks_around3000, ponds_around3000, days_exposition могли бы быть целочисленными
# - first_day_exposition не datatime
# - is_apartment заявлена как булева, но по причине пропусков object

# %% [markdown]
# <a id='Предобработка_данных'></a>
# ### Предобработка данных
# [Оглавление](#Оглавление)

# %% [markdown]
# <a id='Обработка_пропусков'></a>
# #### Обработка пропусков
# [Оглавление](#Оглавление)

# %%
data.isnull().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# <a id='Столбец_ceiling_height'></a>
# #### Столбец ceiling_height (высота потолков)
# [Оглавление](#Оглавление)

# %%
data['ceiling_height'].value_counts().to_frame().head(20)
# Out:
#       ceiling_height
# 2.50            3515
# 2.60            1646
# 2.70            1574
# 3.00            1112
# 2.80             993
# 2.55             980
# 2.75             910
# 2.65             676
# 3.20             277
# 3.10             203
# 2.90             164
# 3.30             141
# 2.56             139
# 3.50             130
# 2.57             103
# 2.85             101
# 3.40              92
# 2.54              83
# 2.64              81
# 2.52              79

# %%
data['ceiling_height'] = data['ceiling_height'] \
                            .apply(lambda x: np.random.choice(data['ceiling_height'].dropna().values) if np.isnan(x) else x)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера</h2>
#
# Интересный способ 😊
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера</h2>
#
# Обрати внимание, если код не помещается в одну строку, рекомендую переносить код на следующую подстроку с помощью обратного слеша. Так быстрее и понятнее изучать сам код.
#
# </div>

# %% [markdown]
# #### Вывод:
# - Большое кол-во пропусков высоты потолков может возникать из-за простого незнания этой самой высоты.
# - Ее могут не указывать, т.к. не считают достаточно значительной.
# - Неизвестно что хуже, когда ее не указывают или когда неверно измеряют. Так мы получили 183 варианта одного метра разницы.
# - Из уважение ко всем, кто мерил, заменяем пропуски пропорционально представленным значениям

# %%
data.isnull().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# <a id='Столбец_floors_total'></a>
# #### Столбец floors_total (всего этажей в доме)
# [Оглавление](#Оглавление)

# %%
data['floors_total'].median()
# Out:
# 9.0

# %%
data['floors_total'] = data['floors_total'].fillna(9)

# %% [markdown]
# #### Вывод:
# - Пропусков всего 86, похоже просто забыли указать
# - Заменить пропуски можно на любое значение из столбца

# %%
data.isnull().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# <a id='Столбец_living_area'></a>
# #### Столбец living_area (всего этажей в доме)
# [Оглавление](#Оглавление)

# %% [markdown]
# #### Вывод:
# - Пропусков не так много.
# - Заменять пропуски усредненными значениями немного опасно, можем получить значение которое будет меньше площади какой-либо отдельной части жилья или несоразмерно больше  всех вместе взятых пространств помещения.
# - Оставим как имеется. Порекомендуем недопускать публикацию обьявлений без ключевых параметров.

# %% [markdown]
# <a id='is_apartment'></a>
# #### Столбец is_apartment (апартаменты)
# [Оглавление](#Оглавление)

# %%
data['is_apartment'].value_counts().to_frame()
# Out:
#        is_apartment
# False          2725
# True             50

# %%
data['is_apartment'] = data['is_apartment'].fillna(False)

# %%
data['is_apartment'].value_counts().to_frame()
# Out:
#        is_apartment
# False         23649
# True             50

# %% [markdown]
# #### Вывод:
# - Самый игнорируемый столбец.
# - Изучив подобный вид жилья, становится ясно, что если кто-то живет в апартаментах, то он не может этого не знать из-за юридической составляющей.
# - Следует вывод: большинство пропусков были от нежелания разбираться в сути этого параметра. Кто пропустил, тот не знает, кто не знает, тот в апартаментах и не живет.
# - Заменяем все на False

# %% [markdown]
# <a id='Столбец_kitchen_area'></a>
# #### Столбец kitchen_area (площадь кухни)
# [Оглавление](#Оглавление)

# %% [markdown]
# #### Вывод:
# - Поступаем аналогично столбцу [living_area](#Столбец_living_area)

# %% [markdown]
# <a id='Столбец_balcony'></a>
# #### Столбец balcony (число балконов)
# [Оглавление](#Оглавление)

# %%
data.isnull().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area              1903
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %%
data['balcony'].value_counts().to_frame()
# Out:
#      balcony
# 1.0     4195
# 0.0     3758
# 2.0     3659
# 5.0      304
# 4.0      183
# 3.0       81

# %%
data['balcony'] = data['balcony'].fillna(0)

# %% [markdown]
# #### Вывод:
# - Почему игнорируют балконы непонятно.
# - Забыть, что у тебя есть балкон сложно.
# - У кого-то их пять.
# - Либо проблемы в интерфейсе, либо люди без балкона предпочитают избегать эту тему.
# - Выдавать 11,5 тысяч балконов я не буду, пропуски приравниваем к нулю.

# %% [markdown]
# <a id='Столбец_locality_name'></a>
# #### Столбец locality_name (название населённого пункта)
# [Оглавление](#Оглавление)

# %%
data = data.dropna(subset=['locality_name'])

# %%
data['locality_name'].isna().sum()
# Out:
# 0

# %% [markdown]
# #### Вывод:
# - Вина за пропуски лежит на ресурсе, так как он позваляет публиковать обьявления без ключевой информации
# - Пропусков всего 49, вычислять их по расстоянию до ближайшего центра города или аэропорта мы не будем

# %% [markdown]
# <a id='gps'></a>
# #### Картографические пропуски
# [Оглавление](#Оглавление)

# %% [markdown]
# #### Вывод:
# - В задании указано, что все *географические* вычисления производятся автоматически. За пропущенными данными мы обращаемся в технический отдел
# - Пропуски в столбах: airports_nearest, cityCenters_nearest, parks_around3000,
#   parks_nearest, ponds_around3000, ponds_nearest оставляем

# %% [markdown]
# <a id='Столбец_days_exposition'></a>
# #### Столбец days_exposition (сколько дней было размещено объявление (от публикации до снятия))
# [Оглавление](#Оглавление)

# %% [markdown]
# #### Вывод:
# - Пропуск может быть у еще активных обьявлений
# - Техническая причина о которой стоит сообщить
# - Заменять по средним значениям не очень хочется, так как будут выпадать или приписываться месяца.
# - Пропуски есть, но без них у нас более 20 тысяч реальных строк для исследования.
# - Игнорируем.

# %% [markdown]
# <a id='Обработка_дубликатов'></a>
# ### Обработка дубликатов
# [Оглавление](#Оглавление)

# %%
data['locality_name'] = data['locality_name'].str.lower()

# %%
data['locality_name'] = data['locality_name'].str.replace('ё', 'е', regex=True)

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Вывод:
# - Приводим названия к одному регистру и заменяем все "ё" на "е"
#
# ...
#
# - А дубликатов и не завезли

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера</h2>
#
# Достаточно детально обработали наши данные, класс 👍
#
# Здорово, что используешь ссылки, это делает проект ещё презентабельнее 😊
#
# </div>

# %% [markdown]
# <a id='Изменение_типа_данных'></a>
# ### Изменение типа данных
# [Оглавление](#Оглавление)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23650 entries, 0 to 23698
# Data columns (total 22 columns):
# total_images            23650 non-null int64
# last_price              23650 non-null float64
# total_area              23650 non-null float64
# first_day_exposition    23650 non-null object
# rooms                   23650 non-null int64
# ceiling_height          23650 non-null float64
# floors_total            23650 non-null float64
# living_area             21752 non-null float64
# floor                   23650 non-null int64
# is_apartment            23650 non-null bool
# studio                  23650 non-null bool
# open_plan               23650 non-null bool
# kitchen_area            21381 non-null float64
# balcony                 23650 non-null float64
# locality_name           23650 non-null object
# airports_nearest        18116 non-null float64
# cityCenters_nearest     18139 non-null float64
# parks_around3000        18140 non-null float64
# ...

# %% [markdown]
# #### В самом начале были выявлены следующие несоответствия:
# - last_price, floors_total, balcony, parks_around3000, ponds_around3000, days_exposition могли бы быть целочисленными
# - first_day_exposition не datatime
# - is_apartment заявлена как булева, но по причине пропусков object (исправилось после заполнения пропусков)

# %%
to_int = ['last_price', 'floors_total', 'balcony', 'parks_around3000', 'ponds_around3000', 'days_exposition']

# %%
for column in to_int:
    data[column] = data[data[column].notnull()][column].astype('int')

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера</h2>
#
# Отличный способ, и главное автоматизированный.
# </div>

# %%
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format = '%Y-%m-%dT%H:%M:%S')

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 1             7     3350000        40.4           2018-12-04      1
# 2            10     5196000        56.0           2015-08-20      2
# 3             0    64900000       159.0           2015-07-24      3
# 4             2    10000000       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70            16         51.0      8         False   False
# 1            3.20            11         18.6      1         False   False
# 2            3.00             5         34.3      4         False   False
# 3            2.60            14          NaN      9         False   False
# 4            3.03            14         32.0     13         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23650 entries, 0 to 23698
# Data columns (total 22 columns):
# total_images            23650 non-null int64
# last_price              23650 non-null int64
# total_area              23650 non-null float64
# first_day_exposition    23650 non-null datetime64[ns]
# rooms                   23650 non-null int64
# ceiling_height          23650 non-null float64
# floors_total            23650 non-null int64
# living_area             21752 non-null float64
# floor                   23650 non-null int64
# is_apartment            23650 non-null bool
# studio                  23650 non-null bool
# open_plan               23650 non-null bool
# kitchen_area            21381 non-null float64
# balcony                 23650 non-null int64
# locality_name           23650 non-null object
# airports_nearest        18116 non-null float64
# cityCenters_nearest     18139 non-null float64
# parks_around3000        18140 non-null float64
# ...

# %% [markdown]
# #### Вывод:
# - Почти все столбцы теперь имеют нужный тип данных
# - Все картографические и счетчик дней из-за пропусков не поддались переводу

# %% [markdown]
# <a id='Расширение_таблицы'></a>
# ### Модификация таблицы
# [Оглавление](#Оглавление)

# %%
import datetime
import calendar
from time import strptime

# %% [markdown]
# * #### Добавим стоимость квадратного метра

# %%
data['sq_meter_price'] = data['last_price'] / data['total_area']

# %% [markdown]
# * #### Добавим день недели, месяц и год публикации объявления

# %%
days = {0:'Понедельник', 1:'Вторник', 2:'Среда', 3:'Четверг', 4:'Пятница', 5:'Суббота', 6:'Воскресенье'}

# %%
data['dayOfWeek'] = data['first_day_exposition'].dt.dayofweek.apply(lambda x: days[x])

# %%
data['Mon_Year'] = data['first_day_exposition'].dt.strftime('%b-%Y')

# %% [markdown]
# * #### Добавим категорию этажа

# %%
data['floor_type'] = np.where(data['floor'] == 1, 'первый этаж', 'другой')
data['floor_type'] = np.where(data['floor'] == data['floors_total'], 'последний этаж', data['floor_type'])

# %% [markdown]
# * #### Добавим отношение жилой площади к общей

# %%
data['living / total'] = data['living_area'] / data['total_area']

# %% [markdown]
# * #### Добавим отношение площади кухни к общей

# %%
data['kitchen / total'] = data['kitchen_area'] / data['total_area']

# %%
data.head(20)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20    13000000      108.00           2019-03-07      3
# 1              7     3350000       40.40           2018-12-04      1
# 2             10     5196000       56.00           2015-08-20      2
# 3              0    64900000      159.00           2015-07-24      3
# 4              2    10000000      100.00           2018-06-19      2
# 5             10     2890000       30.40           2018-09-10      1
# 6              6     3700000       37.30           2017-11-02      1
# 7              5     7915000       71.60           2019-04-18      2
# 8             20     2900000       33.16           2018-05-23      1
# 9             18     5400000       61.00           2017-02-26      3
# 10             5     5050000       39.60           2017-11-16      1
# 11             9     3300000       44.00           2018-08-27      2
# 12            10     3890000       54.00           2016-06-30      2
# ...

# %% [markdown]
# <a id='Исследовательский_анализ_данных'></a>
# ### Исследовательский анализ данных
# [Оглавление](#Оглавление)

# %% [markdown]
# <a id='параметры'></a>
# #### Основные параметры помещений
# [Оглавление](#Оглавление)

# %% [markdown]
# <a id='площадь'></a>
# #### Изучим параметр: площадь
# [Оглавление](#Оглавление)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера</h2>
#
# Думаю теперь мы готовы исследовать 😊
#
# </div>

# %%
data['total_area'].describe()
# Out:
# count    23650.000000
# mean        60.329069
# std         35.661808
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.700000
# max        900.000000
# Name: total_area, dtype: float64

# %%
plt.ylim(0, 1000)
plt.title('Определение выбросов total_area')
data.boxplot('total_area')
plt.show()
plt.ylim(0, 150)
plt.title('Определение выбросов total_area')
data.boxplot('total_area')
plt.show()

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера</h2>
#
# <s>Не забывай пожалуйста подписывать каждый график.
#
# Это важный момент всего проекта, так быстрее понять о чем идёт речь. </s>
#
# </div>

# %%
plt.title('Распределение значений total_area')
data.query('total_area <= 115')['total_area'].hist()
plt.show()

# %% [markdown]
# #### Вывод:
# - Большинство помещений имеют площадь 40 - 70 кв. метров
# - 12 кв. метров похоже на комнату, а не полноценное жилье
# - значения 900 и несколько 600 скорей всего результат опечатки
# - более 120 метров можно допустить, это элитные варианты, но 300-500 это явно должны быть 2-3 этажные коттеджы. В записке к данным указано, что это обьявления о продаже квартир, значит это опять опечатки пользователей, 30-50 метров вместо 300-500 отлично соотносятся с нашей гистограммой

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера</h2>
#
# Хорошие и логичные комментарии.
#
# </div>

# %% [markdown]
# <a id='цена'></a>
# #### Изучим параметр: цена
# [Оглавление](#Оглавление)

# %%
data['last_price'].describe()
# Out:
# count    2.365000e+04
# mean     6.541127e+06
# std      1.089640e+07
# min      1.219000e+04
# 25%      3.400000e+06
# 50%      4.650000e+06
# 75%      6.799000e+06
# max      7.630000e+08
# Name: last_price, dtype: float64

# %%
plt.ylim(0, 7.630000e+08)
plt.title('Определение выбросов last_price')
data.boxplot('last_price')
plt.show()
plt.ylim(0 , 2.000000e+07)
plt.title('Определение выбросов last_price')
data.boxplot('last_price')
plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера</h2>
#
# Обрати внимание, что наши действия начинают повторяться.
#
# Это говорит о том, что мы можем создать функцию, которая будет воспроизводить нужный нам код.
#
# </div>

# %%
data.query('last_price < 3.400000e+06').sort_values('last_price')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 8793              7       12190       109.0           2019-03-20      2
# 17456             7      430000        30.4           2019-04-22      1
# 14911             5      430000        54.0           2018-06-26      2
# 16274            18      440000        40.0           2018-07-10      1
# 16219            14      450000        38.5           2018-07-11      2
# ...             ...         ...         ...                  ...    ...
# 8188              5     3399000        48.2           2016-10-10      2
# 2400             11     3399000        30.4           2017-11-10      1
# 22991             9     3399000        31.1           2015-03-19      1
# 14808             8     3399000        28.8           2018-08-07      1
# 2088             18     3399000        74.2           2018-03-27      3
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# ...

# %%
plt.title('Распределение значений last_price')
data.query('last_price <= 1.2e+07 and last_price > 0.4e+06')['last_price'].hist()
plt.show()

# %% [markdown]
# #### Вывод:
# - Большинство обьявлений оцениваются в 3,4 - 6,9 млн.
# - максимальная цена на два порядка выше основных значений. Даже если цена обоснована, учитывать ее нестоит
# - Хоть мы и рассматриваем недвижимость, отбрасываем цены выше 12 млн
# - Минимальная цена оказалась двенадцать тысяч, что похоже на предложение аренды. Ошибиться на два нуля проблематично, но всякое бывает
# - Так как минимальная цена не кажется надежной, принимаем за минимальное ближайшее правдободобное значение - 430000 (с него начинается целый ценовой диапазон)

# %% [markdown]
# <a id='комнаты'></a>
# #### Изучим параметр: комнаты
# [Оглавление](#Оглавление)

# %%
data['rooms'].describe()
# Out:
# count    23650.000000
# mean         2.070106
# std          1.078620
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         19.000000
# Name: rooms, dtype: float64

# %%
plt.title('Определение выбросов rooms')
plt.ylim(0, 10)
data.boxplot('rooms')
plt.show()

# %%
plt.title('Распределение значений rooms')
data.query('rooms <= 6')['rooms'].hist()
plt.show()

# %% [markdown]
# #### Вывод:
# - Самый распространенный варианты 1 и 2 комнаты, выглядит крайне нормально
# - Больше 6 комнат мы не рассматриваем, так нам велел график
# - Есть еще довольно распространенный вариант 3 комнаты, конечно уступает, но и не теряется на фоне лидеров

# %% [markdown]
# <a id='потолки'></a>
# #### Изучим параметр: потолки
# [Оглавление](#Оглавление)

# %%
data['ceiling_height'].describe()
# Out:
# count    23650.000000
# mean         2.772693
# std          1.315370
# min          1.000000
# 25%          2.520000
# 50%          2.650000
# 75%          2.800000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %%
plt.title('Определение выбросов ceiling_height')
plt.ylim(3, 100)
data.boxplot('ceiling_height')
plt.show()
plt.title('Определение выбросов ceiling_height')
plt.ylim(3, 4)
data.boxplot('ceiling_height')
plt.show()
plt.title('Определение выбросов ceiling_height')
plt.ylim(2, 3)
data.boxplot('ceiling_height')
plt.show()

# %%
plt.title('Распределение значений ceiling_height')
data.query('ceiling_height <= 3.2 and ceiling_height >= 2.2')['ceiling_height'].hist(bins=50)
plt.show()

# %% [markdown]
# #### Вывод:
# - Стандартом потолков можно признать 2.50, так же выделяются круглые значение 2.60, 2.70, 3.00
# - Есть явные опечатки 25-35м, что полность совпадает с нормальными 2.5-3.0
# - 10-20 метров объяснить сложнее, но мы их и не учитываем

# %% [markdown]
# <a id='Время_продажи'></a>
# ### Время продажи
# [Оглавление](#Оглавление)

# %%
data['days_exposition'].describe()
# Out:
# count    20470.000000
# mean       180.753200
# std        219.777916
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        231.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %%
plt.title('Определение выбросов days_exposition')
plt.ylim(0, 1600)
data.boxplot('days_exposition')
plt.show()
plt.title('Определение выбросов days_exposition')
plt.ylim(0, 600)
data.boxplot('days_exposition')
plt.show()

# %%
plt.title('Распределение значений days_exposition')
data['days_exposition'].hist(bins = 100, range = (0, 500), figsize = (10, 5))
plt.show()
plt.title('Распределение значений days_exposition')
data['days_exposition'].hist(bins = 100, range = (0, 100), figsize = (10, 5))
plt.show()

# %%
data['days_exposition'].mean()
# Out:
# 180.7531998045921

# %%
data['days_exposition'].median()
# Out:
# 95.0

# %% [markdown]
# #### Вывод:
# - Т.к. есть объявления длительностью  от 500 до 1600 дней, медианное и средниее значения не отражают действительные сроки
# - Значительная часть объявлений закрывается в первые два месяца после публикации, что можно считать быстрой продажей
# - Продажи, которые заняли более 200 дней можно считать крайне долгими, как по графику, так и по календарю
# - Есть пики на 45, 60 и 90 днях. Обычно на подобных ресурсах объявления не висят вечно, нужно переодически подтверждать их актуальность, иначе они автоматически исчезают из выдачи до повторной публикации. Скорей всего это мы и наблюдаем.

# %% [markdown]
# <div class="alert alert-danger">
# <h2> Комментарий ревьюера</h2>
#
# <s>Давай постараемся автоматизировать построение графиков через цикл `for`.
#
# Почему это важно?
#
# - экономим своё время
# - оптимизируем код
# - делаем работу презентабельнее
#
# Выбери любой участок, где это сделать целесообразнее всего. </s>
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# Я решил автоматизировать первый пункт шага 4.
#
#
# Для возможности сравнить было/стало я добавил код ниже, не удаляя ничего изначального.
#
# Постороение графиков было автоматизировано, но лимиты все равно пришлость к каждому устанавливать в несколько шагов.
#
# Гистограммы получились наиболее автоматизированы, для них лимиты уже были готовы в предыдущем шаге.
#
# <b>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера (2)</h2>
#
# Супер 👍
#
#
# Обрати внимание, что мы можем сделать это автоматически. Посчитав минимальный и максимальный уровень нормального распределения для атрибута `range`. Можно найти в открытом доступе в интеренете, как это сделать.
#
# </div>

# %%
data[['total_area', 'last_price', 'rooms', 'ceiling_height']].describe()
# Out:
#          total_area    last_price         rooms  ceiling_height
# count  23650.000000  2.365000e+04  23650.000000    23650.000000
# mean      60.329069  6.541127e+06      2.070106        2.772693
# std       35.661808  1.089640e+07      1.078620        1.315370
# min       12.000000  1.219000e+04      0.000000        1.000000
# 25%       40.000000  3.400000e+06      1.000000        2.520000
# 50%       52.000000  4.650000e+06      2.000000        2.650000
# 75%       69.700000  6.799000e+06      3.000000        2.800000
# max      900.000000  7.630000e+08     19.000000      100.000000

# %%
columns = ['total_area', 'last_price', 'rooms', 'ceiling_height']

top_lims = [120, 1.63e+07, 19, 3.5]
bot_lims = [10, -1, -1, 2]

for x in range(len(columns)):
    
    data.boxplot(columns[x], figsize = (5, 5)).set_ylim(bot_lims[x], top_lims[x])
    plt.title(f'Определение выбросов {columns[x]}')
    plt.show()

# %%
for x in range(len(columns)):
    
    data.query(f'{columns[x]} <= {top_lims[x]} and {columns[x]} > {bot_lims[x]}')[columns[x]].hist(bins = 'auto')
    plt.title(f'Распределение значений {columns[x]}')
    plt.show()

# %% [markdown]
# <a id='Влияние_факторов'></a>
# ### Влияние факторов на стоимость
# [Оглавление](#Оглавление)

# %% [markdown]
# #### Влияние площади, количества комнат и удаленности от центра города

# %%
import seaborn as sb

# %%
heat = data[['last_price', 'total_area', 'rooms', 'cityCenters_nearest']].corr() \
            .sort_values('last_price', ascending=False).filter(items = ['last_price'])

# %%
plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера</h2>
#
# Кстати можно визуализировать матрицу корреляции.
#
# В этом нам поможет библиотека `seaborn` и готовый в ней метод `heatmap`.
#
# </div>

# %% [markdown]
# #### Влияние этажа на стоимость

# %%
plt.ylim(3750000, 5000000)
data.groupby('floor_type').median()['last_price'].plot(kind = 'bar')
plt.show()

# %% [markdown]
# #### Влияние дня недели на стоимость

# %%
plt.ylim(4500000, 4750000)
data.groupby('dayOfWeek').median()['last_price'].sort_values().plot(kind="bar")
plt.show()

# %% [markdown]
# #### Влияние месяца на стоимость

# %%
data['month'] = data['first_day_exposition'].dt.strftime('%b')

# %%
plt.ylim(4200000, 4900000)
data.groupby('month').median()['last_price'].plot(kind="bar", figsize = (10, 5))
plt.show()

# %% [markdown]
# #### Влияние года на стоимость

# %%
data['year'] = data['first_day_exposition'].dt.strftime('%Y')

# %%
plt.ylim(4200000, 8000000)
data.groupby('year').median()['last_price'].plot(kind="bar", figsize = (10, 5))
plt.show()

# %% [markdown]
# #### Вывод:
# - Цена сильно зависит от площади
# - Цена в  меньшей мере зависит от кол-ва комнат (связано с площадью)
# - Цена слабо зависит от удаленности от центра города.
# - Первый и последний этажи заметно уступают по стоимости промежуточным вариантам
# - Со вторника по воскресенье запрашиваемые цены снижаются. С понедельника по вторник люди наиболее жадные при публикации объявлений
# - Апрель выглядит наилучшим месяцем для продажи и наихудшим для покупки недвижимости. Обратное можно сказать про июнь. Но доверять таким графикам нестоит, т.к. 1-2 года могут исказить цены на несколько лет вокруг
# - Примерно об этом было сказано раньше. Цены в 2014 почти в 1,5 раза выше чем в послеующих.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера</h2>
#
# Логично и понятно.
#
# Чем дальше делаем, тем больше мы узнаем инсайтов.
#
# </div>

# %% [markdown]
# <a id='населённых_пунктов'></a>
# ### 10 населённых пунктов с наибольшим числом объявлений
# [Оглавление](#Оглавление)

# %%
top_local = data['locality_name'].value_counts().head(10)

# %%
top_local_names = list(top_local.index)

# %%
data.query('locality_name in @top_local_names').pivot_table(index= 'locality_name', values = 'sq_meter_price')\
                            .sort_values('sq_meter_price', ascending=False)
# Out:
#                    sq_meter_price
# locality_name
# санкт-петербург     114849.008794
# пушкин              103125.819291
# деревня кудрово      92473.547576
# поселок парголово    90175.913458
# поселок мурино       85681.762601
# поселок шушары       78677.364217
# колпино              75424.579098
# гатчина              68746.146763
# всеволожск           68654.473986
# выборг               58141.909153

# %% [markdown]
# #### Вывод:
# - Ожидаемо самое дорогое жилье в Санкт-Петербурге
# - Цена метра в Выборге в два раза меньше чем у лидера списка

# %% [markdown]
# <a id='центральной_зоны'></a>
# ### Определение центральной зоны
# [Оглавление](#Оглавление)

# %%
data.query('locality_name == "санкт-петербург"')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20    13000000      108.00           2019-03-07      3
# 2                10     5196000       56.00           2015-08-20      2
# 3                 0    64900000      159.00           2015-07-24      3
# 4                 2    10000000      100.00           2018-06-19      2
# 7                 5     7915000       71.60           2019-04-18      2
# ...             ...         ...         ...                  ...    ...
# 23689            13     3550000       35.30           2018-02-28      1
# 23690             3     5500000       52.00           2018-07-19      2
# 23691            11     9470000       72.90           2016-10-13      2
# 23694             9     9700000      133.81           2017-03-21      3
# 23697            13    11475000       76.75           2017-03-28      2
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# ...

# %%
data['cityCenters_km'] = (data['cityCenters_nearest'] / 1000).round()

# %%
data['cityCenters_km'].head()
# Out:
# 0    16.0
# 1    19.0
# 2    14.0
# 3     7.0
# 4     8.0
# Name: cityCenters_km, dtype: float64

# %%
data.query('locality_name == "санкт-петербург"').groupby('cityCenters_km')\
                            .median()['last_price'].plot(kind = 'bar', figsize = (20, 5))
plt.show()

# %% [markdown]
# #### Вывод:
# - В самом центре цены существенно выше
# - Начиная с 9 км цены проседают и выравниваются, похоже, примерно на этой отметке и заканчивается центр.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера</h2>
#
# Согласен, потому что после этого километра идёт длительная стагнация.
#
# </div>

# %% [markdown]
# <a id='Сегмент_квартир'></a>
# ### Сегмент квартир в центре
# [Оглавление](#Оглавление)

# %%
data.query('locality_name == "санкт-петербург" and cityCenters_km < 9')['total_area'].hist(bins = 60, range = (0, 120))
plt.show()
data.query('locality_name == "санкт-петербург" and cityCenters_km > 9')['total_area'].hist(bins = 60, range = (0, 120))
plt.show()

# %%
data.query('locality_name == "санкт-петербург" and cityCenters_km < 9')['last_price'].describe()
# Out:
# count    4.122000e+03
# mean     1.418037e+07
# std      2.358049e+07
# min      1.600000e+06
# 25%      6.450000e+06
# 50%      8.960000e+06
# 75%      1.390000e+07
# max      7.630000e+08
# Name: last_price, dtype: float64

# %%
data.query('locality_name == "санкт-петербург" and cityCenters_km < 9 and last_price <= 1.2e+07 and last_price > 0.4e+06')\
                                            ['last_price'].hist(bins = 30)
plt.show()
data.query('locality_name == "санкт-петербург" and cityCenters_km > 9 and last_price <= 1.2e+07 and last_price > 0.4e+06')\
                                            ['last_price'].hist(bins = 30)
plt.show()

# %%
data.query('locality_name == "санкт-петербург" and cityCenters_km < 9 and rooms <= 6')['rooms'].hist(bins = 30)
plt.show()
data.query('locality_name == "санкт-петербург" and cityCenters_km > 9 and rooms <= 6')['rooms'].hist(bins = 30)
plt.show()

# %%
data.query('locality_name == "санкт-петербург" and cityCenters_km < 9 and ceiling_height <= 3.2 and ceiling_height >= 2.2')\
                                                                    ['ceiling_height'].hist(bins=100)
plt.show()
data.query('locality_name == "санкт-петербург" and cityCenters_km > 9 and ceiling_height <= 3.2 and ceiling_height >= 2.2')\
                                                                    ['ceiling_height'].hist(bins=100)
plt.show()

# %%
corr1 = data.query('locality_name == "санкт-петербург" and cityCenters_km < 9').corr()\
        .sort_values('last_price', ascending=False).filter(items = ['last_price']).reset_index()
corr1
# Out:
#                   index  last_price
# 0            last_price    1.000000
# 1        sq_meter_price    0.776671
# 2            total_area    0.638837
# 3           living_area    0.542762
# 4          kitchen_area    0.504713
# 5                 rooms    0.340541
# 6          total_images    0.130218
# 7      parks_around3000    0.112871
# 8                 floor    0.110693
# 9      ponds_around3000    0.109154
# 10      days_exposition    0.065507
# 11              balcony    0.054572
# 12     airports_nearest    0.054232
# 13         is_apartment    0.034033
# 14       ceiling_height    0.030716
# 15         floors_total    0.027916
# 16            open_plan    0.005853
# 17       living / total   -0.017179
# 18               studio   -0.025098
# 19        parks_nearest   -0.042640
# 20       cityCenters_km   -0.076020
# 21  cityCenters_nearest   -0.078142
# 22        ponds_nearest   -0.079614
# 23      kitchen / total   -0.089242

# %%
corr2 = data.query('locality_name == "санкт-петербург" and cityCenters_km > 9')\
        .corr().sort_values('last_price', ascending=False).filter(items = ['last_price']).reset_index()

# %%
corr_total = corr1.merge(corr2, on='index')
corr_total
# Out:
#                   index  last_price_x  last_price_y
# 0            last_price      1.000000      1.000000
# 1        sq_meter_price      0.776671      0.499284
# 2            total_area      0.638837      0.830361
# 3           living_area      0.542762      0.700103
# 4          kitchen_area      0.504713      0.653381
# 5                 rooms      0.340541      0.519381
# 6          total_images      0.130218      0.177835
# 7      parks_around3000      0.112871      0.085298
# 8                 floor      0.110693      0.130739
# 9      ponds_around3000      0.109154      0.097877
# 10      days_exposition      0.065507      0.092920
# 11              balcony      0.054572      0.108703
# 12     airports_nearest      0.054232      0.087099
# 13         is_apartment      0.034033      0.003423
# 14       ceiling_height      0.030716      0.032523
# 15         floors_total      0.027916      0.163954
# 16            open_plan      0.005853     -0.035281
# ...

# %% [markdown]
# #### Вывод:
# - Площадь квартир в центре больше (50 - 85) / За пределами центра площади скромнее (30 - 60)
# - Цены в центре  5 - 8 млн / За пределами центра 3 - 5.5 млн
# - Комнат в центре чаще всего 3 - 2 и даже 4 / За пределами же центра широко распространены 1 и 2х комнатные квартиры
# - У потолков в центре незначительно лидирует отметка 3 / За пределами центра доминируют потолки 2.5
# - Кол-во комнат сильнее влияет на цену за пределами центра

# %% [markdown]
# <a id='Общий_вывод'></a>
# ### Общий вывод
# [Оглавление](#Оглавление)

# %%
corr3 = data.query('locality_name != "санкт-петербург"').corr()\
        .sort_values('last_price', ascending=False).filter(items = ['last_price']).reset_index()

# %%
corr4 = corr_total.merge(corr3, on='index')

# %%
plt.figure(figsize=(10,10))
sb.heatmap(data.corr()[['last_price']].sort_values(by='last_price', ascending=False), annot=True, cmap='coolwarm', fmt='.2f')
plt.show()

# %% [markdown]
# - Цена за квадратный метр оказывае существенное влияние на стоимость жилья (очевидно, но что есть)
# - В центре Петербурга стоимость жилья зависит слабее от метража, чем за его пределами
# - Кол-во комнат имеет разное влияние на цену в центре города, за пределами центра и в области
# - Дальность от аэропорта постоянно на слуху, но имеет весьма умеренное влияние на стоимость жилья
# - Кол-во этажей в центре города значительно слабее влияет на цену, чем за его пределами

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера</h2>
#
# Выводы логичны и понятны.
#
# Давай поправим автоматизацию графиков и небольшие желтые комментарии.
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>
# Что было доработано:
#
# *    Где увидел, пренес код через " \ "
# * Автоматизировал один раздел
# *    Подписал "старые" графики в разделе, который автоматизировал. Даже для относительно небольшого раздела полностью прочувствовал достоинство автоматического заполнений. Остальные графики остались без внимания из-за своего кол-ва, но теперь изначально буду следить за этим
# *   Познакомился с seaborn-heatmap
#
#
#
# </b>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера (2)</h2>
#
# Здорово, что получилось поправить замечания в проекте, думаю мы узнали много полезного.
#
# В целом сам проект выполнен на хорошем уровне! На протяжении всей работы чувствуется глубина проработки задачи и это безусловный плюс для нас.
#
# Не стоит забывать про оформление своей работы, это важный такой же важный этап. Рекомендую «не стесняться» использовать ячейки типа **markdown** там где нам необходимо отобразить свои размышления, в том числе с использованием дополнительной стилизации.
#
# Успехов тебе в новых проектах!
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера (2)</h2>
#
# Рекомендую посмотреть на дополнительную стилизацию ячеек типа **markdown**.
#
# **Жирный**
# *Курсив*
#
# ---
#
# # Заголовок первого уровня
#
# ---
#
# ## Заголовок первого уровня
#
# ---
# Списки:
#
# - один
# - два
# - три
#
# ---
#
# 1. Раз
# 2. Раз раз
# 3. Раз два три
#
# ---
#
# Отображение `переменных`
#
#
# ---
#
# Также здесь можно найти все, что нужно:
#
# https://www.notion.so/35d9c2f32ffa42f3b17010737aedca4b
#
# </div>

# %% [markdown]
# ### Чек-лист готовности проекта
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [ ]  файлы изучены (выведены первые строки, метод info())
# - [ ]  определены пропущенные значения
# - [ ]  заполнены пропущенные значения
# - [ ]  есть пояснение, какие пропущенные значения обнаружены
# - [ ]  изменены типы данных
# - [ ]  есть пояснение, в каких столбцах изменены типы и почему
# - [ ]  посчитано и добавлено в таблицу: цена квадратного метра
# - [ ]  посчитано и добавлено в таблицу: день недели, месяц и год публикации объявления
# - [ ]  посчитано и добавлено в таблицу: этаж квартиры; варианты — первый, последний, другой
# - [ ]  посчитано и добавлено в таблицу: соотношение жилой и общей площади, а также отношение площади кухни к общей
# - [ ]  изучены следующие параметры: площадь, цена, число комнат, высота потолков
# - [ ]  построены гистограммы для каждого параметра
# - [ ]  выполнено задание: "Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?"
# - [ ]  выполнено задание: "Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили."
# - [ ]  выполнено задание: "Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от квадратного метра, числа комнат, этажа (первого или последнего), удалённости от центра. Также изучите зависимость от даты размещения: дня недели, месяца и года. "Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце '*locality_name'*. "
# - [ ]  выполнено задание: "Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге (*'locality_name'*). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона. "
# - [ ]  выполнено задание: "Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всему городу?"
# - [ ]  в каждом этапе есть выводы
# - [ ]  есть общий вывод
